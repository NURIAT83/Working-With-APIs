# %% [markdown]
# # Use this notbook for your 3 choices of APIs

# %%
from bs4 import BeautifulSoup
import requests
from time import sleep
from random import randint
import json
import pandas as pd

# %%
base_url ="https://api.carbonintensity.org.uk/"
endpoint="intensity"

r=requests.get(base_url+endpoint)

carbon_uk=r.json()

print( carbon_uk)
# Out:
# {'data': [{'from': '2024-05-12T22:00Z', 'to': '2024-05-12T22:30Z', 'intensity': {'forecast': 111, 'actual': 105, 'index': 'low'}}]}

# %%
carbon_pd=pd.DataFrame.from_dict(carbon_uk)

# %%
carbon_pd
# Out:
#                                                 data
# 0  {'from': '2024-05-12T22:00Z', 'to': '2024-05-1...

# %%
carbon_final=pd.DataFrame(carbon_pd['data'].tolist())

# %%
base_url ="https://www.mercadobitcoin.net/api/BTC/trades/1501871369/1501891200/"


r=requests.get(base_url)

bitcoin=r.json()

print( bitcoin)
# Out:
# [{'amount': 0.002, 'date': 1501871382, 'price': 9723, 'tid': 739718, 'type': 'sell'}, {'amount': 0.0177606, 'date': 1501871387, 'price': 9735, 'tid': 739719, 'type': 'buy'}, {'amount': 0.06385831, 'date': 1501871387, 'price': 9738, 'tid': 739720, 'type': 'buy'}, {'amount': 0.03298915, 'date': 1501871387, 'price': 9738, 'tid': 739721, 'type': 'buy'}, {'amount': 0.00441, 'date': 1501871388, 'price': 9723, 'tid': 739722, 'type': 'sell'}, {'amount': 0.09427603, 'date': 1501871401, 'price': 9738, 'tid': 739723, 'type': 'buy'}, {'amount': 0.00919, 'date': 1501871402, 'price': 9723, 'tid': 739724, 'type': 'sell'}, {'amount': 0.0151344, 'date': 1501871402, 'price': 9711, 'tid': 739725, 'type': 'sell'}, {'amount': 0.1049356, 'date': 1501871402, 'price': 9710, 'tid': 739726, 'type': 'sell'}, {'amount': 0.2107, 'date': 1501871406, 'price': 9710, 'tid': 739727, 'type': 'sell'}, {'amount': 0.01986137, 'date': 1501871407, 'price': 9738, 'tid': 739728, 'type': 'buy'}, {'amount': 0.003, 'date': 1501
# ...

# %%
bitcoin_pd=pd.DataFrame.from_dict(bitcoin)

# %%
bitcoin_pd
# Out:
#        amount        date    price     tid  type
# 0    0.002000  1501871382  9723.00  739718  sell
# 1    0.017761  1501871387  9735.00  739719   buy
# 2    0.063858  1501871387  9738.00  739720   buy
# 3    0.032989  1501871387  9738.00  739721   buy
# 4    0.004410  1501871388  9723.00  739722  sell
# ..        ...         ...      ...     ...   ...
# 961  0.015340  1501891048  9600.00  740679  sell
# 962  0.025240  1501891050  9600.00  740680  sell
# 963  0.009155  1501891050  9655.99  740681   buy
# 964  0.019884  1501891149  9655.98  740682   buy
# 965  0.022980  1501891188  9601.00  740683  sell
#
# [966 rows x 5 columns]

# %%
base_url="https://archive-api.open-meteo.com/v1/archive?latitude=48.8534&longitude=2.3488&start_date=2024-05-01&end_date=2024-05-01&hourly=temperature_2m&daily=temperature_2m_max,temperature_2m_min,precipitation_sum"

# %%
r=requests.get(base_url)

weather=r.json()

print(weather)
# Out:
# {'latitude': 48.822495, 'longitude': 2.2881355, 'generationtime_ms': 0.1590251922607422, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 43.0, 'hourly_units': {'time': 'iso8601', 'temperature_2m': '°C'}, 'hourly': {'time': ['2024-05-01T00:00', '2024-05-01T01:00', '2024-05-01T02:00', '2024-05-01T03:00', '2024-05-01T04:00', '2024-05-01T05:00', '2024-05-01T06:00', '2024-05-01T07:00', '2024-05-01T08:00', '2024-05-01T09:00', '2024-05-01T10:00', '2024-05-01T11:00', '2024-05-01T12:00', '2024-05-01T13:00', '2024-05-01T14:00', '2024-05-01T15:00', '2024-05-01T16:00', '2024-05-01T17:00', '2024-05-01T18:00', '2024-05-01T19:00', '2024-05-01T20:00', '2024-05-01T21:00', '2024-05-01T22:00', '2024-05-01T23:00'], 'temperature_2m': [12.8, 13.1, 12.4, 12.2, 11.9, 11.6, 12.6, 13.9, 15.8, 17.3, 18.9, 18.9, 19.2, 18.9, 19.3, 19.4, 19.4, 18.6, 16.3, 14.8, 14.1, 13.1, 12.2, 11.9]}, 'daily_units': {'time': 'iso8601', 'temperature_2m_max': '°C', 'temperature_2m_min': '°
# ...

# %%
weather_pd=pd.DataFrame.from_dict(weather)

# %%
weather_pd
# Out:
#                      latitude  longitude  generationtime_ms  \
# time                48.822495   2.288136           0.159025
# temperature_2m      48.822495   2.288136           0.159025
# temperature_2m_max  48.822495   2.288136           0.159025
# temperature_2m_min  48.822495   2.288136           0.159025
# precipitation_sum   48.822495   2.288136           0.159025
#
#                     utc_offset_seconds timezone timezone_abbreviation  \
# time                                 0      GMT                   GMT
# temperature_2m                       0      GMT                   GMT
# temperature_2m_max                   0      GMT                   GMT
# temperature_2m_min                   0      GMT                   GMT
# precipitation_sum                    0      GMT                   GMT
#
#                     elevation hourly_units  \
# time                     43.0      iso8601
# temperature_2m           43.0           °C
# temperature_2m_max       43.0          NaN
# ...

# %%
base_url="https://api.tvmaze.com/schedule?country=US&date=2014-12-01"

# %%
r=requests.get(base_url)

tv_schedule=r.json()

print(tv_schedule)
# Out:
# [{'id': 2586958, 'url': 'https://www.tvmaze.com/episodes/2586958/morning-joe-2014-12-01-episode-239', 'name': 'Episode 239', 'season': 2014, 'number': 239, 'type': 'regular', 'airdate': '2014-12-01', 'airtime': '06:00', 'airstamp': '2014-12-01T11:00:00+00:00', 'runtime': 180, 'rating': {'average': None}, 'image': None, 'summary': None, 'show': {'id': 15309, 'url': 'https://www.tvmaze.com/shows/15309/morning-joe', 'name': 'Morning Joe', 'type': 'News', 'language': 'English', 'genres': [], 'status': 'Running', 'runtime': 240, 'averageRuntime': 187, 'premiered': '2006-04-09', 'ended': None, 'officialSite': 'https://www.nbc.com/morning-joe', 'schedule': {'time': '06:00', 'days': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']}, 'rating': {'average': 1.2}, 'weight': 85, 'network': {'id': 201, 'name': 'MSNBC', 'country': {'name': 'United States', 'code': 'US', 'timezone': 'America/New_York'}, 'officialSite': None}, 'webChannel': None, 'dvdCountry': None, 'externals': {'tvrage': No
# ...

# %%
tv_schedule_pd=pd.DataFrame.from_dict(tv_schedule)

# %%
tv_schedule_pd
# Out:
#          id                                                url  \
# 0   2586958  https://www.tvmaze.com/episodes/2586958/mornin...
# 1    339141  https://www.tvmaze.com/episodes/339141/clarenc...
# 2    471370  https://www.tvmaze.com/episodes/471370/odd-squ...
# 3    626815  https://www.tvmaze.com/episodes/626815/democra...
# 4    751694  https://www.tvmaze.com/episodes/751694/rachael...
# ..      ...                                                ...
# 77  1843024  https://www.tvmaze.com/episodes/1843024/are-yo...
# 78    57116  https://www.tvmaze.com/episodes/57116/the-colb...
# 79    63659  https://www.tvmaze.com/episodes/63659/the-toni...
# 80   122672  https://www.tvmaze.com/episodes/122672/jimmy-k...
# 81   359991  https://www.tvmaze.com/episodes/359991/dr-phil...
#
#                                                  name  season  number  \
# 0                                         Episode 239    2014   239.0
# ...
